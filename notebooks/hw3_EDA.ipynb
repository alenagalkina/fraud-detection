# %%
#!pip install pyspark

# %%
#!pip install findspark

# %%
# %pylab inline
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import findspark
findspark.init()

# %%
from pyspark.sql.functions import min, max, count, when, isnan, col, countDistinct, hour, minute, second
from pyspark.sql.types import TimestampType, DoubleType, IntegerType, StringType, StructType, StructField

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession
        .builder
        .appName("OTUS")
        .config("spark.dynamicAllocation.enabled", "true")
        .config("spark.executor.memory", "2g")
        .config("spark.driver.memory", "1g")
        .getOrCreate()
)

# %%
#посмотреть содержание папок hdfs
! hdfs dfs -ls
# Out:
# Found 41 items
# drwxr-xr-x   - ubuntu hadoop          0 2023-05-28 11:37 .sparkStaging
# -rw-r--r--   1 ubuntu hadoop 2807409271 2023-05-18 09:28 2019-08-22.txt
# -rw-r--r--   1 ubuntu hadoop 2854479008 2023-05-18 09:28 2019-09-21.txt
# -rw-r--r--   1 ubuntu hadoop 2895460543 2023-05-18 09:27 2019-10-21.txt
# -rw-r--r--   1 ubuntu hadoop 2939120942 2023-05-18 09:28 2019-11-20.txt
# -rw-r--r--   1 ubuntu hadoop 2995462277 2023-05-18 09:26 2019-12-20.txt
# -rw-r--r--   1 ubuntu hadoop 2994906767 2023-05-18 09:28 2020-01-19.txt
# -rw-r--r--   1 ubuntu hadoop 2995431240 2023-05-18 09:29 2020-02-18.txt
# -rw-r--r--   1 ubuntu hadoop 2995176166 2023-05-18 09:26 2020-03-19.txt
# -rw-r--r--   1 ubuntu hadoop 2996034632 2023-05-18 09:25 2020-04-18.txt
# -rw-r--r--   1 ubuntu hadoop 2995666965 2023-05-18 09:29 2020-05-18.txt
# -rw-r--r--   1 ubuntu hadoop 2994699401 2023-05-18 09:29 2020-06-17.txt
# -rw-r--r--   1 ubuntu hadoop 2995810010 2023-05-18 09:28 2020-07-17.txt
# -rw-r--r--   1 ubuntu hadoop 2995995152 2023-05-18 09:27 2020-08-16.txt
# -rw-r--r--   1 ubuntu hadoop 2995778382 2023-05-18 09:25 2020-09-15.txt
# -rw-r--r--   1 ubuntu hadoop 2995868596 2023-05-18 09:26 2020-10-15.txt
# -rw-r--r--   1 ubuntu hadoop 2995467533 2023-05-18 09:27 2020-11-14.txt
# -rw-r--r--   1 ubuntu hadoop 2994761624 2023-05-18 09:28 2020-12-14.txt
# -rw-r--r--   1 ubuntu hadoop 2995390576 2023-05-18 09:26 2021-01-13.txt
# -rw-r--r--   1 ubuntu hadoop 2995780517 2023-05-18 09:30 2021-02-12.txt
# -rw-r--r--   1 ubuntu hadoop 2995191659 2023-05-18 09:26 2021-03-14.txt
# -rw-r--r--   1 ubuntu hadoop 2995446495 2023-05-18 09:26 2021-04-13.txt
# -rw-r--r--   1 ubuntu hadoop 3029170975 2023-05-18 09:25 2021-05-13.txt
# -rw-r--r--   1 ubuntu hadoop 3042691991 2023-05-18 09:26 2021-06-12.txt
# -rw-r--r--   1 ubuntu hadoop 3041980335 2023-05-18 09:30 2021-07-12.txt
# -rw-r--r--   1 ubuntu hadoop 3042662187 2023-05-18 09:29 2021-08-11.txt
# -rw-r--r--   1 ubuntu hadoop 3042455173 2023-05-18 09:29 2021-09-10.txt
# -rw-r--r--   1 ubuntu hadoop 3042424238 2023-05-18 09:30 2021-10-10.txt
# -rw-r--r--   1 ubuntu hadoop 3042358698 2023-05-18 09:26 2021-11-09.txt
# -rw-r--r--   1 ubuntu hadoop 3042923985 2023-05-18 09:29 2021-12-09.txt
# -rw-r--r--   1 ubuntu hadoop 3042868087 2023-05-18 09:29 2022-01-08.txt
# -rw-r--r--   1 ubuntu hadoop 3043148790 2023-05-18 09:28 2022-02-07.txt
# -rw-r--r--   1 ubuntu hadoop 3042312191 2023-05-18 09:29 2022-03-09.txt
# -rw-r--r--   1 ubuntu hadoop 3041973966 2023-05-18 09:30 2022-04-08.txt
# -rw-r--r--   1 ubuntu hadoop 3073760161 2023-05-18 09:30 2022-05-08.txt
# -rw-r--r--   1 ubuntu hadoop 3089378246 2023-05-18 09:30 2022-06-07.txt
# -rw-r--r--   1 ubuntu hadoop 3089589719 2023-05-18 09:28 2022-07-07.txt
# -rw-r--r--   1 ubuntu hadoop 3090000257 2023-05-18 09:28 2022-08-06.txt
# -rw-r--r--   1 ubuntu hadoop 3089390874 2023-05-18 09:28 2022-09-05.txt
# -rw-r--r--   1 ubuntu hadoop 3109468067 2023-05-18 09:28 2022-10-05.txt
# -rw-r--r--   1 ubuntu hadoop 3136657969 2023-05-18 09:29 2022-11-04.txt

# %%
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)  # to pretty print pyspark.DataFrame in jupyter

# %% [markdown]
# ### EDA на выборке

# %%
data = spark.read.text("2019-09-21.txt")

# %%
data.show(10)
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |# tranaction_id |...|
# |46988237,2019-09-...|
# |46988238,2019-09-...|
# |46988239,2019-09-...|
# |46988240,2019-09-...|
# |46988241,2019-09-...|
# |46988242,2019-09-...|
# |46988243,2019-09-...|
# |46988244,2019-09-...|
# |46988245,2019-09-...|
# +--------------------+
# only showing top 10 rows

# %%
#extract first row as this is our header
header=data.first()[0]
schema=header.split(" | ")

# %%
print(schema)
# Out:
# ['# tranaction_id', 'tx_datetime', 'customer_id', 'terminal_id', 'tx_amount', 'tx_time_seconds', 'tx_time_days', 'tx_fraud', 'tx_fraud_scenario']

# %%
#filter the header, separate the columns and apply the schema
df_new = data.filter(data["value"] != header).rdd.map(lambda x:x[0].split(",")).toDF(schema)
df_new.show()
# Out:
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |# tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |       46988237|2019-09-21 09:45:59|          1|        178|    83.11|        2627159|          30|       0|                0|
# |       46988238|2019-09-21 19:33:01|          2|        660|    22.15|        2662381|          30|       0|                0|
# |       46988239|2019-09-21 18:06:19|          3|        732|    36.83|        2657179|          30|       0|                0|
# |       46988240|2019-09-21 16:56:01|         10|        663|    19.30|        2652961|          30|       0|                0|
# |       46988241|2019-09-21 05:34:26|         10|        145|   106.51|        2612066|          30|       0|                0|
# |       46988242|2019-09-21 12:12:51|         11|        337|    53.97|        2635971|          30|       0|                0|
# |       46988243|2019-09-21 11:05:32|         11|        973|    29.30|        2631932|          30|       0|                0|
# |       46988244|2019-09-21 15:13:40|         11|        975|    28.59|        2646820|          30|       0|                0|
# |       46988245|2019-09-21 16:47:20|         12|        522|    88.02|        2652440|          30|       0|                0|
# |       46988246|2019-09-21 07:57:03|         12|        522|    77.39|        2620623|          30|       0|                0|
# |       46988247|2019-09-21 14:47:46|         13|         51|    84.32|        2645266|          30|       0|                0|
# |       46988248|2019-09-21 07:04:56|         13|        440|    43.30|        2617496|          30|       0|                0|
# |       46988249|2019-09-21 06:49:40|         13|        819|    72.70|        2616580|          30|       0|                0|
# |       46988250|2019-09-21 19:53:28|         14|        892|     1.46|        2663608|          30|       0|                0|
# |       46988251|2019-09-21 19:04:13|         15|        505|    52.54|        2660653|          30|       1|                2|
# |       46988252|2019-09-21 07:34:48|         15|        145|    34.87|        2619288|          30|       0|                0|
# |       46988253|2019-09-21 06:53:08|         18|        182|    66.25|        2616788|          30|       0|                0|
# |       46988254|2019-09-21 08:57:22|         18|        561|   107.31|        2624242|          30|       0|                0|
# |       46988255|2019-09-21 06:49:38|         21|        273|    83.25|        2616578|          30|       0|                0|
# |       46988256|2019-09-21 07:55:29|         21|        375|    93.28|        2620529|          30|       0|                0|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# only showing top 20 rows

# %%
df_new.select([count(when(col(c).contains('None') | \
                            col(c).contains('NULL') | \
                            (col(c) == '' ) | \
                            col(c).isNull() | \
                            isnan(c), c 
                           )).alias(c)
                    for c in df_new.columns[2:]])
# Out:
# +-----------+-----------+---------+---------------+------------+--------+-----------------+
# |customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +-----------+-----------+---------+---------------+------------+--------+-----------------+
# |          0|        778|        0|              0|           0|       0|                0|
# +-----------+-----------+---------+---------------+------------+--------+-----------------+

# %% [markdown]
# #### 1. Data-Type Constraints – e.g., values in a particular column must be of a particular data type, e.g., Boolean, numeric (integer or real), date, etc.

# %%
df_new = df_new.withColumn("tx_datetime", df_new.tx_datetime.cast(TimestampType()))\
        .withColumn("customer_id", df_new.customer_id.cast(IntegerType()))\
        .withColumn("terminal_id", df_new.terminal_id.cast(IntegerType()))\
        .withColumn("tx_amount", df_new.tx_amount.cast(DoubleType()))\
        .withColumn("tx_time_seconds", df_new.tx_time_seconds.cast(IntegerType()))\
        .withColumn("tx_time_days", df_new.tx_time_days.cast(IntegerType()))\
        .withColumn("tx_fraud", df_new.tx_fraud.cast(IntegerType()))\
        .withColumn("tx_fraud_scenario", df_new.tx_fraud_scenario.cast(IntegerType()))

# %%
df_new.printSchema()
# Out:
# root
#  |-- # tranaction_id: string (nullable = true)
#  |-- tx_datetime: timestamp (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- terminal_id: integer (nullable = true)
#  |-- tx_amount: double (nullable = true)
#  |-- tx_time_seconds: integer (nullable = true)
#  |-- tx_time_days: integer (nullable = true)
#  |-- tx_fraud: integer (nullable = true)
#  |-- tx_fraud_scenario: integer (nullable = true)

# %%
df_new = df_new.withColumn("hour", hour(col("tx_datetime")))\
        .withColumn("minute", minute(col("tx_datetime")))\
        .withColumn("second", second(col("tx_datetime")))

# %%
df_new
# Out:
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |# tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|hour|minute|second|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |       46988237|2019-09-21 09:45:59|          1|        178|    83.11|        2627159|          30|       0|                0|   9|    45|    59|
# |       46988238|2019-09-21 19:33:01|          2|        660|    22.15|        2662381|          30|       0|                0|  19|    33|     1|
# |       46988239|2019-09-21 18:06:19|          3|        732|    36.83|        2657179|          30|       0|                0|  18|     6|    19|
# |       46988240|2019-09-21 16:56:01|         10|        663|     19.3|        2652961|          30|       0|                0|  16|    56|     1|
# |       46988241|2019-09-21 05:34:26|         10|        145|   106.51|        2612066|          30|       0|                0|   5|    34|    26|
# |       46988242|2019-09-21 12:12:51|         11|        337|    53.97|        2635971|          30|       0|                0|  12|    12|    51|
# |       46988243|2019-09-21 11:05:32|         11|        973|     29.3|        2631932|          30|       0|                0|  11|     5|    32|
# |       46988244|2019-09-21 15:13:40|         11|        975|    28.59|        2646820|          30|       0|                0|  15|    13|    40|
# |       46988245|2019-09-21 16:47:20|         12|        522|    88.02|        2652440|          30|       0|                0|  16|    47|    20|
# |       46988246|2019-09-21 07:57:03|         12|        522|    77.39|        2620623|          30|       0|                0|   7|    57|     3|
# |       46988247|2019-09-21 14:47:46|         13|         51|    84.32|        2645266|          30|       0|                0|  14|    47|    46|
# |       46988248|2019-09-21 07:04:56|         13|        440|     43.3|        2617496|          30|       0|                0|   7|     4|    56|
# |       46988249|2019-09-21 06:49:40|         13|        819|     72.7|        2616580|          30|       0|                0|   6|    49|    40|
# |       46988250|2019-09-21 19:53:28|         14|        892|     1.46|        2663608|          30|       0|                0|  19|    53|    28|
# |       46988251|2019-09-21 19:04:13|         15|        505|    52.54|        2660653|          30|       1|                2|  19|     4|    13|
# |       46988252|2019-09-21 07:34:48|         15|        145|    34.87|        2619288|          30|       0|                0|   7|    34|    48|
# |       46988253|2019-09-21 06:53:08|         18|        182|    66.25|        2616788|          30|       0|                0|   6|    53|     8|
# |       46988254|2019-09-21 08:57:22|         18|        561|   107.31|        2624242|          30|       0|                0|   8|    57|    22|
# |       46988255|2019-09-21 06:49:38|         21|        273|    83.25|        2616578|          30|       0|                0|   6|    49|    38|
# |       46988256|2019-09-21 07:55:29|         21|        375|    93.28|        2620529|          30|       0|                0|   7|    55|    29|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# only showing top 20 rows

# %%
df_new.select(min("tx_datetime"), max("tx_datetime")).first()
# Out:
# Row(min(tx_datetime)=datetime.datetime(2019, 9, 21, 0, 0), max(tx_datetime)=datetime.datetime(2019, 10, 20, 23, 59, 59))

# %%
df_new.select(min("hour"), max("hour"), min("minute"), max("minute"), min("second"), max("second")).first()
# Out:
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)

# %% [markdown]
# #### 2. Range Constraints: typically, numbers or dates should fall within a certain range. That is, they have minimum and/or maximum permissible values.

# %%
df_new.summary()
# Out:
# +-------+--------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|   tx_time_seconds|      tx_time_days|            tx_fraud|  tx_fraud_scenario|              hour|            minute|            second|
# +-------+--------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+
# |  count|            46994586|         46994586|          46993808|          46994586|          46994586|          46994586|            46994586|           46994586|          46994483|          46994483|          46994483|
# |   mean|        7.04855295E7|500408.7910296518|26131.415391065988| 54.23517020109595|3887961.7464464735|44.499569929182904|0.057127133751109116|0.11508919346581753|11.499809371240449|29.499881720158513|29.503239539841303|
# | stddev|1.3566168583115075E7|  288605.71890121|1514438.6991362155|41.309001673721376| 748103.2080479839| 8.656042958590001|  0.2320853840435848|0.46959559949215074| 5.059005945167615|17.317712944087045|17.318269042539246|
# |    min|            46988237|          -999999|                 0|               0.0|           2592000|                30|                   0|                  0|                 0|                 0|                 0|
# |    25%|         5.8734146E7|           250719|               197|             21.94|           3239912|                37|                   0|                  0|                 8|                15|                15|
# |    50%|         7.0487852E7|           500719|               511|             45.42|           3888462|                44|                   0|                  0|                12|                30|                30|
# |    75%|         8.2232017E7|           750218|               797|             77.81|           4535930|                52|                   0|                  0|                15|                45|                45|
# |    max|            93982822|           999999|          89518096|           4303.07|           5184000|                59|                   1|                  3|                23|                59|                59|
# +-------+--------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+------------------+------------------+------------------+

# %% [markdown]
# Что обнаружено:
#
# * customer_id = -999999; 999999
#
# * tx_amount = 0.0

# %%
df_new[df_new.tx_amount == 0.0]
# Out:
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |# tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|hour|minute|second|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |       47061238|2019-09-21 03:26:32|      46539|        707|      0.0|        2604392|          30|       0|                0|   3|    26|    32|
# |       47154330|2019-09-21 21:33:19|     105987|        870|      0.0|        2669599|          30|       0|                0|  21|    33|    19|
# |       47165461|2019-09-21 13:32:23|     113020|        100|      0.0|        2640743|          30|       1|                2|  13|    32|    23|
# |       47181299|2019-09-21 12:35:54|     123313|        251|      0.0|        2637354|          30|       0|                0|  12|    35|    54|
# |       47227073|2019-09-21 05:15:53|     152548|        891|      0.0|        2610953|          30|       0|                0|   5|    15|    53|
# |       47228403|2019-09-21 19:02:19|     153348|        160|      0.0|        2660539|          30|       0|                0|  19|     2|    19|
# |       47350288|2019-09-21 13:55:31|     231601|        435|      0.0|        2642131|          30|       0|                0|  13|    55|    31|
# |       47426689|2019-09-21 11:10:10|     280295|        816|      0.0|        2632210|          30|       0|                0|  11|    10|    10|
# |       47486538|2019-09-21 04:57:51|     318725|        337|      0.0|        2609871|          30|       0|                0|   4|    57|    51|
# |       47544251|2019-09-21 16:15:48|     355184|        516|      0.0|        2650548|          30|       0|                0|  16|    15|    48|
# |       47614133|2019-09-21 14:43:08|     399357|        265|      0.0|        2644988|          30|       0|                0|  14|    43|     8|
# |       47660632|2019-09-21 04:50:30|     428954|        596|      0.0|        2609430|          30|       0|                0|   4|    50|    30|
# |       47684853|2019-09-21 17:10:15|     444485|        622|      0.0|        2653815|          30|       0|                0|  17|    10|    15|
# |       47749586|2019-09-21 11:02:33|     485882|        521|      0.0|        2631753|          30|       0|                0|  11|     2|    33|
# |       47855578|2019-09-21 19:59:28|     553549|        529|      0.0|        2663968|          30|       0|                0|  19|    59|    28|
# |       47877747|2019-09-21 06:50:26|     567639|        145|      0.0|        2616626|          30|       0|                0|   6|    50|    26|
# |       47919300|2019-09-21 05:38:13|     593825|        115|      0.0|        2612293|          30|       0|                0|   5|    38|    13|
# |       47964791|2019-09-21 09:10:09|     622833|        543|      0.0|        2625009|          30|       1|                2|   9|    10|     9|
# |       48062041|2019-09-21 00:47:47|     684884|        720|      0.0|        2594867|          30|       0|                0|   0|    47|    47|
# |       48099427|2019-09-21 03:45:19|     708640|        724|      0.0|        2605519|          30|       0|                0|   3|    45|    19|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# only showing top 20 rows

# %%
df_new[df_new.customer_id == -999999]
# Out:
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |# tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|hour|minute|second|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |       47009347|2019-09-21 19:52:15|    -999999|        779|   107.75|        2663535|          30|       0|                0|  19|    52|    15|
# |       47079004|2019-09-21 09:35:34|    -999999|        972|    11.88|        2626534|          30|       0|                0|   9|    35|    34|
# |       47105774|2019-09-21 10:29:57|    -999999|        403|      7.6|        2629797|          30|       0|                0|  10|    29|    57|
# |       47158695|2019-09-21 13:56:17|    -999999|        710|     5.57|        2642177|          30|       0|                0|  13|    56|    17|
# |       47392780|2019-09-21 07:49:27|    -999999|        481|    74.61|        2620167|          30|       0|                0|   7|    49|    27|
# |       47440508|2019-09-21 13:53:24|    -999999|        754|    63.82|        2642004|          30|       0|                0|  13|    53|    24|
# |       47503116|2019-09-21 19:08:16|    -999999|        114|    54.13|        2660896|          30|       0|                0|  19|     8|    16|
# |       47549817|2019-09-21 16:43:46|    -999999|        132|    26.74|        2652226|          30|       0|                0|  16|    43|    46|
# |       47668930|2019-09-21 10:27:52|    -999999|        831|    24.74|        2629672|          30|       0|                0|  10|    27|    52|
# |       47673768|2019-09-21 11:38:18|    -999999|        580|    63.21|        2633898|          30|       0|                0|  11|    38|    18|
# |       47787651|2019-09-21 08:09:27|    -999999|          9|    52.31|        2621367|          30|       0|                0|   8|     9|    27|
# |       47880840|2019-09-21 10:50:38|    -999999|        880|     59.7|        2631038|          30|       0|                0|  10|    50|    38|
# |       47990222|2019-09-21 09:08:26|    -999999|        958|    57.42|        2624906|          30|       0|                0|   9|     8|    26|
# |       48079485|2019-09-21 20:18:53|    -999999|        971|    25.13|        2665133|          30|       0|                0|  20|    18|    53|
# |       48114562|2019-09-21 15:41:05|    -999999|        331|    99.89|        2648465|          30|       1|                2|  15|    41|     5|
# |       48117694|2019-09-21 10:00:04|    -999999|        913|     7.31|        2628004|          30|       0|                0|  10|     0|     4|
# |       48229332|2019-09-21 10:30:04|    -999999|        281|   139.85|        2629804|          30|       0|                0|  10|    30|     4|
# |       48327896|2019-09-21 07:28:17|    -999999|        521|    47.41|        2618897|          30|       0|                0|   7|    28|    17|
# |       48501332|2019-09-21 08:54:42|    -999999|        145|    62.36|        2624082|          30|       0|                0|   8|    54|    42|
# |       48515672|2019-09-21 01:05:00|    -999999|        392|    53.95|        2595900|          30|       0|                0|   1|     5|     0|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# only showing top 20 rows

# %%
df_new[df_new.customer_id == 999999]
# Out:
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |# tranaction_id|        tx_datetime|customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|hour|minute|second|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |       50124028|2019-09-22 04:18:50|     999999|        488|    25.47|        2693930|          31|       0|                0|   4|    18|    50|
# |       50124029|2019-09-22 13:56:59|     999999|        920|    37.56|        2728619|          31|       0|                0|  13|    56|    59|
# |       50124030|2019-09-22 15:49:08|     999999|        374|    42.99|        2735348|          31|       0|                0|  15|    49|     8|
# |       56388538|2019-09-26 14:33:06|     999999|        374|    31.56|        3076386|          35|       0|                0|  14|    33|     6|
# |       61087255|2019-09-29 08:18:41|     999999|        548|    34.81|        3313121|          38|       0|                0|   8|    18|    41|
# |       61087256|2019-09-29 09:53:19|     999999|        354|    32.94|        3318799|          38|       0|                0|   9|    53|    19|
# |       62653437|2019-09-30 20:04:37|     999999|        498|    49.47|        3441877|          39|       0|                0|  20|     4|    37|
# |       64220672|2019-10-01 10:50:39|     999999|        735|    28.45|        3495039|          40|       0|                0|  10|    50|    39|
# |       64220673|2019-10-01 12:12:32|     999999|        881|    34.04|        3499952|          40|       0|                0|  12|    12|    32|
# |       65786156|2019-10-02 15:51:07|     999999|          4|    27.72|        3599467|          41|       0|                0|  15|    51|     7|
# |       70485864|2019-10-05 12:11:19|     999999|        735|    47.92|        3845479|          44|       0|                0|  12|    11|    19|
# |       75186443|2019-10-08 14:46:42|     999999|        226|    25.98|        4114002|          47|       0|                0|  14|    46|    42|
# |       78317556|2019-10-10 11:50:33|     999999|        920|     31.7|        4276233|          49|       0|                0|  11|    50|    33|
# |       86148879|2019-10-15 08:17:12|     999999|          4|     19.6|        4695432|          54|       0|                0|   8|    17|    12|
# |       87715407|2019-10-16 08:18:04|     999999|        881|    25.15|        4781884|          55|       0|                0|   8|    18|     4|
# |       90849826|2019-10-18 14:01:05|     999999|        354|    57.62|        4975265|          57|       0|                0|  14|     1|     5|
# |       90849827|2019-10-18 08:11:14|     999999|        226|    22.94|        4954274|          57|       0|                0|   8|    11|    14|
# |       92415767|2019-10-19 18:47:43|     999999|          4|    38.95|        5078863|          58|       0|                0|  18|    47|    43|
# |       93982822|2019-10-20 19:33:18|     999999|        735|    29.92|        5167998|          59|       0|                0|  19|    33|    18|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+

# %% [markdown]
# #### 3. Mandatory Constraints: Certain columns cannot be empty

# %%
# Find Count of Null, None, NaN of All DataFrame Columns
df_new.select([count(when(col(c).contains('None') | \
                            col(c).contains('NULL') | \
                            (col(c) == '' ) | \
                            col(c).isNull() | \
                            isnan(c), c 
                           )).alias(c)
                    for c in df_new.columns[2:]])
# Out:
# +-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|hour|minute|second|
# +-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+
# |          0|        778|        0|              0|           0|       0|                0| 103|   103|   103|
# +-----------+-----------+---------+---------------+------------+--------+-----------------+----+------+------+

# %% [markdown]
# #### 4. Unique Constraints: A field, or a combination of fields, must be unique across a dataset.

# %%
df_new.distinct().count()
# Out:
# 46994586

# %%
df_new.select(countDistinct("# tranaction_id"))
# Out:
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994586|
# +-------------------------------+

# %% [markdown]
# Что обнаружено:
#
# * количество уникальных значений меньше, чем общее количество строк, обнаружены дубликаты строк

# %% [markdown]
# #### 5. Set-Membership constraints: The values for a column come from a set of discrete values or codes.

# %%
df_new.groupBy("tx_fraud").count()
# Out:
# +--------+--------+
# |tx_fraud|   count|
# +--------+--------+
# |       1| 2684666|
# |       0|44309920|
# +--------+--------+

# %%
df_new.groupBy("tx_fraud_scenario").count()
# Out:
# +-----------------+--------+
# |tx_fraud_scenario|   count|
# +-----------------+--------+
# |                1|   25433|
# |                3|   64670|
# |                2| 2594563|
# |                0|44309920|
# +-----------------+--------+

# %% [markdown]
# ### EDA на всем датасете

# %%
import subprocess

dir_in = "/data"
args = "hdfs dfs -ls | awk '{print $8}'"
proc = subprocess.Popen(args, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)

s_output, s_err = proc.communicate()
all_dart_dirs = s_output.split()
all_dart_dirs = all_dart_dirs[1:]

# %%
def basic_info(path):
    data = spark.read.text(path)
    header=data.first()[0]
    schema=header.split(" | ")
    df_new = data.filter(data["value"] != header).rdd.map(lambda x:x[0].split(",")).toDF(schema)
    df_new = df_new.withColumn("tx_datetime", df_new.tx_datetime.cast(TimestampType()))\
        .withColumn("customer_id", df_new.customer_id.cast(IntegerType()))\
        .withColumn("terminal_id", df_new.terminal_id.cast(IntegerType()))\
        .withColumn("tx_amount", df_new.tx_amount.cast(DoubleType()))\
        .withColumn("tx_time_seconds", df_new.tx_time_seconds.cast(IntegerType()))\
        .withColumn("tx_time_days", df_new.tx_time_days.cast(IntegerType()))\
        .withColumn("tx_fraud", df_new.tx_fraud.cast(IntegerType()))\
        .withColumn("tx_fraud_scenario", df_new.tx_fraud_scenario.cast(IntegerType()))
    print(df_new.summary())
    print(df_new.select(min("tx_datetime"), max("tx_datetime")).first())
    print(df_new.select(countDistinct("# tranaction_id")))

# %%
for path in all_dart_dirs[:3]:
    print(str(path)[2:-1])
    basic_info(str(path)[2:-1])
# Out:
# 2019-08-22.txt
# +-------+--------------------+------------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|   tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
# |  count|            46988418|          46988418|          46988418|         46988418|          46988418|         46988418|           46988418|           46988418|
# |   mean|2.3494115552178305E7|500433.83151635365|26597.231571533222|54.23395999456729|1296054.5003670265| 14.5006346883183|0.05377931642644364|0.10841507794537794|
# | stddev|1.3564333711807257E7| 288539.1737685039|1528137.6620335372|41.25033514383643| 748049.5087349451|8.655415884394312|0.22558169835808653| 0.4568780500029875|
# |    min|                   0|           -999999|                 0|              0.0|                 0|                0|                  0|                  0|
# |    25%|         1.1750217E7|            250734|               198|            21.96|            648045|                7|                  0|                  0|
# |    50%|         2.3491787E7|            500810|               511|             45.4|           1296193|               14|                  0|                  0|
# |    75%|         3.5239012E7|            750136|               797|            77.78|           1944078|               22|                  0|                  0|
# |    max|             9999999|            999999|          89518096|          3773.34|           2592000|               29|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2019, 8, 22, 0, 0), max(tx_datetime)=datetime.datetime(2019, 9, 20, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46988237|
# +-------------------------------+
#
# 2019-09-21.txt
# +-------+--------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|   tx_time_seconds|      tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+
# |  count|            46994586|         46994586|          46993808|          46994586|          46994586|          46994586|            46994586|           46994586|
# |   mean|        7.04855295E7|500408.7910296518|26131.415391065988| 54.23517020109595|3887961.7464464735|44.499569929182904|0.057127133751109116|0.11508919346581753|
# | stddev|1.3566168583115073E7|  288605.71890121|1514438.6991362153|41.309001673721376| 748103.2080479839| 8.656042958590001|  0.2320853840435848|0.46959559949215074|
# |    min|            46988237|          -999999|                 0|               0.0|           2592000|                30|                   0|                  0|
# |    25%|         5.8734146E7|           250700|               197|             21.94|           3239912|                37|                   0|                  0|
# |    50%|         7.0483253E7|           500719|               511|             45.42|           3887893|                44|                   0|                  0|
# |    75%|         8.2232017E7|           750218|               797|             77.81|           4535908|                52|                   0|                  0|
# |    max|            93982822|           999999|          89518096|           4303.07|           5184000|                59|                   1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+------------------+------------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2019, 9, 21, 0, 0), max(tx_datetime)=datetime.datetime(2019, 10, 20, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994586|
# +-------------------------------+
#
# 2019-10-21.txt
# +-------+--------------------+-----------------+------------------+-----------------+-----------------+-----------------+--------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|  tx_time_seconds|     tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+-----------------+-----------------+--------------------+-------------------+
# |  count|            46994432|         46994432|          46994095|         46994432|         46994432|         46994432|            46994432|           46994432|
# |   mean|1.1747998834602457E8|500459.0007606007|25609.197394523715|54.22942989288503|6480042.166121361|74.50047422639346|0.061309050399843114|0.12345920044315037|
# | stddev|1.3566092568324871E7|288559.2743272898| 1498937.858170725|41.21476215222664|748136.0158995113|8.656436486468424|   0.239896335869331| 0.4850677955801512|
# |    min|           100000000|                0|                 0|              0.0|          5184000|               60|                   0|                  0|
# |    25%|        1.05730407E8|           250804|               198|            21.95|          5831826|               67|                   0|                  0|
# |    50%|        1.17478741E8|           500784|               511|             45.4|          6479385|               75|                   0|                  0|
# |    75%|        1.29230928E8|           750211|               797|            77.79|          7128113|               82|                   0|                  0|
# |    max|            99999999|           999999|          89518096|          3521.11|          7776000|               89|                   1|                  3|
# +-------+--------------------+-----------------+------------------+-----------------+-----------------+-----------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2019, 10, 21, 0, 0), max(tx_datetime)=datetime.datetime(2019, 11, 19, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994326|
# +-------------------------------+

# %%
for path in all_dart_dirs[3:]:
    print(str(path)[2:-1])
    basic_info(str(path)[2:-1])
# Out:
# 2019-11-20.txt
# +-------+--------------------+------------------+------------------+-----------------+-----------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|  tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-----------------+------------------+-------------------+-------------------+
# |  count|            46992239|          46992239|          46990303|         46992239|         46992239|          46992239|           46992239|           46992239|
# |   mean|1.6447322476824638E8|500459.87731093215|27049.256139059158|54.23781666627963|9071959.531695394|104.49993331877631|0.05227031212537032|0.10539791474928445|
# | stddev|1.3565467724042192E7|288546.72727632715| 1541322.190585709|41.30263273238161|748176.4890162547| 8.655355111644191| 0.2225716236402647| 0.4509415384972227|
# |    min|           140977149|           -999999|                 0|              0.0|            72099|                90|                  0|                  0|
# |    25%|        1.52724022E8|            250820|               197|            21.96|          8423948|                97|                  0|                  0|
# |    50%|        1.64474302E8|            500776|               511|            45.41|          9071902|               105|                  0|                  0|
# |    75%|        1.76217396E8|            750189|               797|            77.78|          9720074|               112|                  0|                  0|
# |    max|           187969298|            999999|          89518096|          4857.51|         10368000|               119|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-----------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2019, 11, 20, 0, 0), max(tx_datetime)=datetime.datetime(2019, 12, 19, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46992150|
# +-------------------------------+
#
# 2019-12-20.txt
# +-------+--------------------+-----------------+------------------+------------------+--------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|     tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+--------------------+------------------+-------------------+-------------------+
# |  count|            46994937|         46994937|          46993889|          46994937|            46994937|          46994937|           46994937|           46994937|
# |   mean|2.1146676700000003E8|500415.2723298469|26443.479383159796|54.227280341496694|1.1663850907935338E7|134.49843358657975|0.05102696488347245|0.10291002198811332|
# | stddev| 1.356626990808733E7|288577.1724246683|1523636.9970132085|  41.2659717268669|   748123.3580468916| 8.655504924619635|0.22005275451274217|0.44596494849524987|
# |    min|           187969299|                0|                 0|               0.0|               69060|               120|                  0|                  0|
# |    25%|        1.99715426E8|           250721|               197|             21.95|            11015891|               127|                  0|                  0|
# |    50%|        2.11465493E8|           500697|               511|             45.42|            11662294|               134|                  0|                  0|
# |    75%|        2.23212834E8|           750192|               797|             77.78|            12311854|               142|                  0|                  0|
# |    max|           234964235|           999999|          89518096|           4289.59|            12960000|               149|                  1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+--------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2019, 12, 20, 0, 0), max(tx_datetime)=datetime.datetime(2020, 1, 18, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994937|
# +-------------------------------+
#
# 2020-01-19.txt
# +-------+--------------------+------------------+-----------------+------------------+------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|      terminal_id|         tx_amount|   tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+-----------------+------------------+------------------+------------------+-------------------+-------------------+
# |  count|            46986197|          46986197|         46986197|          46986197|          46986197|          46986197|           46986197|           46986197|
# |   mean|2.5845731195066598E8|500423.55133140483|26609.61669072728|  54.2331567983678|1.42558648411877E7|164.49839051668727| 0.0507065511175548|0.10225415774764661|
# | stddev|1.3563734330362225E7| 288557.5092410845|1528508.360753998|41.282511784190184| 748119.0204890012|  8.65616017883153|0.21939780722645216| 0.4445964223885188|
# |    min|           234964236|           -999999|                0|               0.0|          12960001|               150|                  0|                  0|
# |    25%|        2.46710618E8|            250764|              197|             21.95|          13607838|               157|                  0|                  0|
# |    50%|        2.58455135E8|            500725|              511|             45.41|          14253652|               164|                  0|                  0|
# |    75%|        2.70205538E8|            750189|              797|             77.79|          14903866|               172|                  0|                  0|
# |    max|           281950386|            999999|         89518096|           3968.55|          15552000|               179|                  1|                  3|
# +-------+--------------------+------------------+-----------------+------------------+------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 1, 19, 0, 0, 1), max(tx_datetime)=datetime.datetime(2020, 2, 17, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46986151|
# +-------------------------------+
#
# 2020-02-18.txt
# +-------+--------------------+------------------+------------------+------------------+--------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|         tx_amount|     tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+------------------+--------------------+------------------+-------------------+-------------------+
# |  count|            46994271|          46994271|          46993777|          46994271|            46994271|          46994271|           46994271|           46994271|
# |   mean|3.0544752199999994E8| 500416.4477006357|27155.825003468013|54.241205992960154|1.6847875328314893E7|194.50034801050538|0.05250584693610844|0.10585805235706285|
# | stddev|1.3566077650447685E7|288541.00220427325|1544413.2675588853| 41.30076670116685|   749198.4251612645| 8.655457594697724| 0.2230448027465541|0.45182267660969894|
# |    min|           281950387|                 0|                 0|               0.0|               49731|               180|                  0|                  0|
# |    25%|        2.93696483E8|            250756|               197|             21.95|            16199975|               187|                  0|                  0|
# |    50%|        3.05445835E8|            500685|               511|             45.42|            16847999|               194|                  0|                  0|
# |    75%|        3.17193777E8|            750171|               797|              77.8|            17496061|               202|                  0|                  0|
# |    max|           328944657|            999999|          89518096|           3995.03|            18144000|               209|                  1|                  3|
# +-------+--------------------+------------------+------------------+------------------+--------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 2, 18, 0, 0), max(tx_datetime)=datetime.datetime(2020, 3, 18, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994271|
# +-------------------------------+
#
# 2020-03-19.txt
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+------------------+--------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|     tx_time_seconds|      tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+------------------+--------------------+-------------------+
# |  count|            46990424|         46990424|          46987185|         46990424|            46990424|          46990424|            46990424|           46990424|
# |   mean|3.5243986950000006E8|500420.4311134541|26930.996190833735|54.22560546633941|1.9439960922893863E7|224.49955610104732|0.053705005939082395| 0.1082602702201623|
# | stddev|  1.35649671172049E7|288588.4764396315|1537886.1210333076|41.22376564846779|   747988.4176116864| 8.654706737975083|  0.2254346454245205|0.45654588826277753|
# |    min|           328944658|          -999999|                 0|              0.0|            18144000|               210|                   0|                  0|
# |    25%|        3.40690678E8|           250733|               197|            21.95|            18792032|               217|                   0|                  0|
# |    50%|        3.52435814E8|           500773|               511|            45.41|            19440280|               224|                   0|                  0|
# |    75%|        3.64185832E8|           750196|               797|            77.78|            20087990|               232|                   0|                  0|
# |    max|           375935081|           999999|          89518096|          4622.26|            20736000|               239|                   1|                  3|
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+------------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 3, 19, 0, 0), max(tx_datetime)=datetime.datetime(2020, 4, 17, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46990424|
# +-------------------------------+
#
# 2020-04-18.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |  count|            47001235|          47001235|          47001068|         47001235|           47001235|          47001235|           47001235|           47001235|
# |   mean| 3.994356715522171E8| 500399.2460601088|20828.820872410815|54.24845349531741|2.203181378520426E7|254.50106657835693|0.07738909413763277|0.15566995207679118|
# | stddev|1.3568071361104049E7|288631.89634211955|1348739.8628069034|41.32914042953819|  750792.3047978195| 8.655687288939342|0.26720782878744165| 0.5392971761330079|
# |    min|           375935082|           -999999|                 0|              0.0|               3088|               240|                  0|                  0|
# |    25%|        3.87684075E8|            250737|               199|            21.95|           21383991|               247|                  0|                  0|
# |    50%|        3.99439065E8|            500729|               512|            45.42|           22033250|               255|                  0|                  0|
# |    75%|        4.11184759E8|            750173|               797|             77.8|           22680042|               262|                  0|                  0|
# |    max|           422936261|            999999|          89518096|          4245.65|           23328000|               269|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 4, 18, 0, 0), max(tx_datetime)=datetime.datetime(2020, 5, 17, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47001180|
# +-------------------------------+
#
# 2020-05-18.txt
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|         tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+-------------------+
# |  count|            46998002|          46998002|          46998002|          46998002|           46998002|          46998002|           46998002|           46998002|
# |   mean| 4.464351688876817E8| 500460.5445234459| 27022.21723368155| 54.23030532787254|2.462393390379608E7|284.50041225156764|   0.05091844117118|0.10269738700806898|
# | stddev|1.3567101611773651E7|288555.90617919277|1540532.4331673346|41.300813947451296|  749207.0094601444| 8.655557645114166|0.21983119557544287| 0.4455552239762688|
# |    min|           422936262|                 0|                 0|               0.0|              35718|               270|                  0|                  0|
# |    25%|        4.34682533E8|            250817|               197|             21.95|           23975967|               277|                  0|                  0|
# |    50%|        4.46431927E8|            500714|               511|              45.4|           24623495|               284|                  0|                  0|
# |    75%|        4.58185051E8|            750218|               797|             77.78|           25272028|               292|                  0|                  0|
# |    max|           469934076|            999999|          89518096|           4257.49|           25920000|               299|                  1|                  3|
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 5, 18, 0, 0), max(tx_datetime)=datetime.datetime(2020, 6, 16, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46997815|
# +-------------------------------+
#
# 2020-06-17.txt
# +-------+--------------------+------------------+------------------+-----------------+--------------------+------------------+--------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|     tx_time_seconds|      tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+--------------------+------------------+--------------------+-------------------+
# |  count|            46983063|          46983063|          46981424|         46983063|            46983063|          46983063|            46983063|           46983063|
# |   mean|4.9342560800000006E8| 500385.8959879649| 26329.99701190411|54.23215234647412|2.7215979347681165E7|314.49979370225395|0.050161927501406196|0.10117969532978299|
# | stddev| 1.356284217953914E7|288661.71524737816|1520311.1354626843|41.34015249763298|    748085.134405093| 8.655877322027406|  0.2182789718338765| 0.4424781538868662|
# |    min|           469934077|           -999999|                 0|              0.0|            25920000|               300|                   0|                  0|
# |    25%|        4.81680262E8|            250668|               197|            21.95|            26567880|               307|                   0|                  0|
# |    50%|        4.93426599E8|            500723|               511|             45.4|            27215410|               315|                   0|                  0|
# |    75%|        5.05173544E8|            750214|               797|            77.78|            27863972|               322|                   0|                  0|
# |    max|           516917139|            999999|          89518096|          4748.97|            28512000|               329|                   1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+--------------------+------------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 6, 17, 0, 0), max(tx_datetime)=datetime.datetime(2020, 7, 16, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46983063|
# +-------------------------------+
#
# 2020-07-17.txt
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+--------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|    tx_time_seconds|      tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+--------------------+-------------------+
# |  count|            47000292|         47000292|          46999560|          47000292|           47000292|          47000292|            47000292|           47000292|
# |   mean| 5.404172854999999E8|500441.3094470349|26912.602993581215|54.232307919916806|2.980802962331885E7|344.50129146006157|0.051468744066526226|0.10379799342523234|
# | stddev|1.3567815763433065E7|288584.0109089412|1537351.2124617456|41.274234357187225|  749086.9067257831| 8.654629940281572|  0.2209518352253525|0.44776526450740917|
# |    min|           516917140|          -999999|                 0|               0.0|              30176|               330|                   0|                  0|
# |    25%|         5.2866608E8|           250743|               197|             21.95|           29160030|               337|                   0|                  0|
# |    50%|        5.40419026E8|           500797|               511|             45.41|           29808603|               345|                   0|                  0|
# |    75%|        5.52166121E8|           750193|               797|             77.79|           30455988|               352|                   0|                  0|
# |    max|           563917431|           999999|          89518096|           3998.81|           31104000|               359|                   1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 7, 17, 0, 0), max(tx_datetime)=datetime.datetime(2020, 8, 15, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47000292|
# +-------------------------------+
#
# 2020-08-16.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+--------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|      tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+--------------------+-------------------+
# |  count|            47003159|          47003159|          47003159|         47003159|           47003159|          47003159|            47003159|           47003159|
# |   mean| 5.874190109999999E8|  500411.082301213|27268.567907127264|54.24499743857657|3.239999304704052E7|374.49988918829905|0.050809074343279775| 0.1024650917611729|
# | stddev|1.3568643395043967E7|288609.76084205386|1547675.7492629073|41.35593341183323|  748068.8301589452| 8.655616084605459| 0.21960763496223637|0.44505387798573637|
# |    min|           563917432|           -999999|                 0|              0.0|           31104000|               360|                   0|                  0|
# |    25%|        5.75666966E8|            250745|               197|            21.95|           31751977|               367|                   0|                  0|
# |    50%|        5.87419047E8|            500722|               511|            45.41|           32400194|               374|                   0|                  0|
# |    75%|        5.99168509E8|            750177|               797|            77.79|           33048030|               382|                   0|                  0|
# |    max|           610920590|            999999|          89518096|          4345.19|           33696000|               389|                   1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 8, 16, 0, 0), max(tx_datetime)=datetime.datetime(2020, 9, 14, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47003159|
# +-------------------------------+
#
# 2020-09-15.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
# |  count|            46999865|          46999865|          46996502|         46999865|           46999865|         46999865|            46999865|           46999865|
# |   mean| 6.344205144428105E8|500335.79039937665|26870.417726791668|54.23378180533066|3.499152182285426E7|404.4994695623062|0.052139405081269914|0.10513449347141741|
# | stddev|1.3567687474073866E7|288613.84839714994|1536125.9611844027|41.32869571887769|  754653.4251978317|  8.6556189548606| 0.22230809380351427|0.45041561852580814|
# |    min|           610920591|           -999999|                 0|              0.0|              48264|              390|                   0|                  0|
# |    25%|        6.22670146E8|            250710|               197|            21.95|           34343895|              397|                   0|                  0|
# |    50%|        6.34420697E8|            500621|               511|             45.4|           34990921|              404|                   0|                  0|
# |    75%|        6.46168704E8|            750050|               797|            77.79|           35640037|              412|                   0|                  0|
# |    max|           657920434|            999999|          89518096|          4743.16|           36288000|              419|                   1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 9, 15, 0, 0), max(tx_datetime)=datetime.datetime(2020, 10, 14, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46999844|
# +-------------------------------+
#
# 2020-10-15.txt

# %%
for path in all_dart_dirs[14:]:
    print(str(path)[2:-1])
    basic_info(str(path)[2:-1])
# Out:
# 2020-10-15.txt
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|         tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud| tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+------------------+
# |  count|            47001238|          47001238|          46998898|          47001238|           47001238|          47001238|           47001238|          47001238|
# |   mean| 6.814209840966522E8|500457.73553637037| 27032.93110825705| 54.23049368167651|3.758398264230325E7|434.49979994143985|0.04991462139784488|  0.10067870978207|
# | stddev|1.3568048763479581E7| 288569.9564065086|1540849.5479515449|41.246148088204606|  748096.8014401352| 8.655975066176538|0.21776857665313426|0.4414355421633948|
# |    min|           657920435|           -999999|                 0|               0.0|           36288000|               420|                  0|                 0|
# |    25%|        6.69672157E8|            250814|               197|             21.95|           36935927|               427|                  0|                 0|
# |    50%|        6.81418798E8|            500816|               511|              45.4|           37583579|               435|                  0|                 0|
# |    75%|        6.93173466E8|            750229|               797|             77.78|           38232034|               442|                  0|                 0|
# |    max|           704921527|            999999|          89518096|           3812.68|           38880000|               449|                  1|                 3|
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 10, 15, 0, 0), max(tx_datetime)=datetime.datetime(2020, 11, 13, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47001093|
# +-------------------------------+
#
# 2020-11-14.txt
# +-------+--------------------+------------------+------------------+-----------------+--------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|     tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+--------------------+-----------------+-------------------+-------------------+
# |  count|            46995020|          46995020|          46993045|         46995020|            46995020|         46995020|           46995020|           46995020|
# |   mean| 7.284189452806071E8| 500436.2519566967|26710.587427884275|54.22666867893742|4.0175743778663315E7|464.4984844989959|0.04968747752421427|0.10021634207198976|
# | stddev|1.3566239968842175E7|288579.15678428556| 1531460.331184403|41.30683769113455|   750413.6139878611|8.655324125681448|0.21729848850429784| 0.4404599515496927|
# |    min|           704921528|           -999999|                 0|              0.0|               78787|              450|                  0|                  0|
# |    25%|         7.1666592E8|            250777|               197|            21.95|            39527843|              457|                  0|                  0|
# |    50%|        7.28418561E8|            500683|               511|             45.4|            40174460|              464|                  0|                  0|
# |    75%|        7.40164945E8|            750228|               797|            77.78|            40823970|              472|                  0|                  0|
# |    max|           751916362|            999999|          89518096|          5075.01|            41472000|              479|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+--------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 11, 14, 0, 0), max(tx_datetime)=datetime.datetime(2020, 12, 13, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994835|
# +-------------------------------+
#
# 2020-12-14.txt
# +-------+-------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |summary|    # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+-------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |  count|           46983905|          46983905|          46983590|         46983905|           46983905|          46983905|           46983905|           46983905|
# |   mean|7.754083149999999E8|500398.13045948395|26469.941201257716|54.22504791460031|4.276750055160168E7|494.49837232558684| 0.0529029888001008|0.10665737554168817|
# | stddev|1.356308524400242E7| 288648.4239759604|1524419.0150643277|41.24633508677268|  754803.1614886262|  8.65462626417624|0.22383981692838004|0.45340803308526156|
# |    min|          751916363|           -999999|                 0|              0.0|              17673|               480|                  0|                  0|
# |    25%|       7.63662483E8|            250682|               197|            21.95|           42119960|               487|                  0|                  0|
# |    50%|       7.75407252E8|            500751|               511|             45.4|           42766596|               494|                  0|                  0|
# |    75%|       7.87153799E8|            750236|               797|            77.78|           43415845|               502|                  0|                  0|
# |    max|          798900267|            999999|          89518096|          4811.56|           44064000|               509|                  1|                  3|
# +-------+-------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2020, 12, 14, 0, 0), max(tx_datetime)=datetime.datetime(2021, 1, 12, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46983905|
# +-------------------------------+
#
# 2021-01-13.txt
# +-------+--------------------+------------------+------------------+------------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|         tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+------------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            46993755|          46993755|          46993755|          46993755|           46993755|         46993755|           46993755|           46993755|
# |   mean| 8.223971115398952E8| 500395.8161760855|27077.533338972382|54.229144511222984|4.535944549785877E7|524.4992996409842|0.05174617350752243|0.10433726779228432|
# | stddev|1.3565906662265934E7|288547.74798518437|1542149.8596398798|41.287769502317296|  757982.0313672228|8.655441964513143| 0.2215141261387212| 0.4487869113248557|
# |    min|           798900268|                 0|                 0|               0.0|              17278|              510|                  0|                  0|
# |    25%|         8.1064756E8|            250739|               197|             21.95|           44711893|              517|                  0|                  0|
# |    50%|        8.22397299E8|            500716|               511|              45.4|           45359586|              524|                  0|                  0|
# |    75%|        8.34141559E8|            750140|               796|             77.78|           46007988|              532|                  0|                  0|
# |    max|           845893949|            999999|          89518096|           4197.42|           46656000|              539|                  1|                  3|
# +-------+--------------------+------------------+------------------+------------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 1, 13, 0, 0), max(tx_datetime)=datetime.datetime(2021, 2, 11, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46993682|
# +-------------------------------+
#
# 2021-02-12.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud| tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+------------------+
# |  count|            46997040|          46997040|          46994864|         46997040|           46997040|         46997040|           46997040|          46997040|
# |   mean| 8.693924633611232E8| 500433.0028605844|14807.866781186982|54.23599771836673|4.795193432378846E7|554.4992774013002| 0.1024653254758172|0.2058130043934682|
# | stddev|1.3566872886348704E7|288586.75349483226| 1131536.349940446|41.31080323474829|  748058.1765609576|8.655556284088856|0.30325926945074894|0.6106905927997135|
# |    min|           845893950|           -999999|                 0|              0.0|           46656000|              540|                  0|                 0|
# |    25%|        8.57639677E8|            250788|               199|            21.95|           47304032|              547|                  0|                 0|
# |    50%|        8.69391244E8|            500769|               511|            45.41|           47950945|              554|                  0|                 0|
# |    75%|        8.81143047E8|            750173|               797|            77.78|           48599973|              562|                  0|                 0|
# |    max|           892890975|            999999|          89518096|          5128.83|           49248000|              569|                  1|                 3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 2, 12, 0, 0), max(tx_datetime)=datetime.datetime(2021, 3, 13, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46997026|
# +-------------------------------+
#
# 2021-03-14.txt
# +-------+--------------------+-----------------+------------------+------------------+--------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|     tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+--------------------+-----------------+-------------------+-------------------+
# |  count|            46990554|         46990554|          46990554|          46990554|            46990554|         46990554|           46990554|           46990554|
# |   mean| 9.163862525000002E8| 500386.057501663| 23861.79755718564|54.225585816673885|5.0543845137172274E7|584.5015141340959|0.06064378385494242|0.12213352496333625|
# | stddev|1.3565004644972354E7|288622.2576643053|1445863.0837505276| 41.25662408269801|   754611.8300505646|8.655831872919947|0.23867575609388314|0.48266458159266856|
# |    min|           892890976|          -999999|                 0|               0.0|               38708|              570|                  0|                  0|
# |    25%|        9.04636937E8|           250694|               197|             21.95|            49896008|              577|                  0|                  0|
# |    50%|        9.16381702E8|           500711|               511|             45.41|            50544763|              584|                  0|                  0|
# |    75%|        9.28136764E8|           750170|               797|             77.79|            51192146|              592|                  0|                  0|
# |    max|           939881529|           999999|          89518096|           3857.23|            51840000|              599|                  1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+--------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 3, 14, 0, 0), max(tx_datetime)=datetime.datetime(2021, 4, 12, 23, 59, 59))

# %%
for path in all_dart_dirs[20:]:
    print(str(path)[2:-1])
    basic_info(str(path)[2:-1])
# Out:
# 2021-04-13.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            46994570|          46994570|          46992906|         46994570|           46994570|         46994570|           46994570|           46994570|
# |   mean| 9.633788144999998E8|500377.17109921423| 26558.23356344466|54.23780637848129|5.313580339001889E7|614.4994623421387|0.05314043728881869|0.10711986512484314|
# | stddev|1.3566163964312918E7| 288541.7384795898|1527004.8167277158|41.25614367717534|  751628.7974476136|8.656297510590337| 0.2243134687981527| 0.4542968358740722|
# |    min|           939881530|                 0|                 0|              0.0|             382436|              600|                  0|                  0|
# |    25%|        9.51627604E8|            250698|               197|            21.95|           52487824|              607|                  0|                  0|
# |    50%|        9.63376983E8|            500711|               511|            45.41|           53134928|              614|                  0|                  0|
# |    75%|        9.75128017E8|            750093|               797|             77.8|           53783973|              622|                  0|                  0|
# |    max|           986876099|            999999|          89518096|          4917.36|           54432000|              629|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 4, 13, 0, 0), max(tx_datetime)=datetime.datetime(2021, 5, 12, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994570|
# +-------------------------------+
#
# 2021-05-13.txt
# +-------+--------------------+------------------+------------------+-----------------+--------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|     tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+--------------------+-----------------+-------------------+-------------------+
# |  count|            46992294|          46992294|          46991698|         46992294|            46992294|         46992294|           46992294|           46992294|
# |   mean|1.0103721851627624E9| 500426.2753579555|26650.563225593593|54.22044721800562|5.5728029251317926E7|644.5013832267904| 0.0545305151521226|0.10991527674728967|
# | stddev|1.3565470317834428E7|288631.01534088235|1529700.6994994588|41.26553191878562|   750206.3192227408|8.655713622329083|0.22706153167479246| 0.4597821652837016|
# |    min|          1000000000|           -999999|                 0|              0.0|              552414|              630|                  0|                  0|
# |    25%|        9.98621558E8|            250760|               197|            21.94|            55079873|              637|                  0|                  0|
# |    50%|       1.010370876E9|            500814|               511|             45.4|            55728000|              645|                  0|                  0|
# |    75%|        1.02211931E9|            750165|               797|            77.77|            56375951|              652|                  0|                  0|
# |    max|           999999999|            999999|          89518096|          5620.61|            57024000|              659|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+--------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 5, 13, 0, 0), max(tx_datetime)=datetime.datetime(2021, 6, 11, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46992171|
# +-------------------------------+
#
# 2021-06-12.txt
# +-------+--------------------+------------------+------------------+----------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|       tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+----------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            46998583|          46998583|          46998008|        46998583|           46998583|         46998583|           46998583|           46998583|
# |   mean|1.0573674959961874E9|500408.24922987574| 26338.36915451821|54.2356161737897|5.832003718554008E7|674.5004224701838|0.05165359985427646|0.10414765057916746|
# | stddev|1.3567284188295985E7| 288557.4512529361|1520547.3994052303|41.3203318439848|   748061.859521065|8.655554721186158| 0.2213266963532587| 0.4484007046498437|
# |    min|          1033868271|                 0|                 0|             0.0|           57024000|              660|                  0|                  0|
# |    25%|        1.04561525E9|            250751|               197|           21.95|           57671973|              667|                  0|                  0|
# |    50%|          1.057368E9|            500681|               511|           45.41|           58320260|              675|                  0|                  0|
# |    75%|       1.069118273E9|            750162|               797|           77.78|           58968159|              682|                  0|                  0|
# |    max|          1080866721|            999999|          89518096|         4487.98|           59616000|              689|                  1|                  3|
# +-------+--------------------+------------------+------------------+----------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 6, 12, 0, 0), max(tx_datetime)=datetime.datetime(2021, 7, 11, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46998451|
# +-------------------------------+
#
# 2021-07-12.txt
# +-------+--------------------+------------------+------------------+------------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|         tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+------------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            46987371|          46987371|          46986900|          46987371|           46987371|         46987371|           46987371|           46987371|
# |   mean|       1.104360407E9|500402.74426230404|26624.510945774247|54.238307626107186|6.091159368580232E7| 704.500947775946|0.05163796033619331|0.10410537759177886|
# | stddev|1.3564085792018982E7|288620.87638805725|1528942.8737194573| 41.27414119695448|  761262.9332070334|8.655442167241644|0.22129501221387343| 0.4482892859988497|
# |    min|          1080866722|           -999999|                 0|               0.0|                500|              690|                  0|                  0|
# |    25%|       1.092612255E9|            250725|               197|             21.95|           60264000|              697|                  0|                  0|
# |    50%|       1.104356308E9|            500797|               511|             45.41|           60911998|              704|                  0|                  0|
# |    75%|       1.116104283E9|            750179|               797|             77.81|           61559977|              712|                  0|                  0|
# |    max|          1127854092|            999999|          89518096|           4404.41|           62208000|              719|                  1|                  3|
# +-------+--------------------+------------------+------------------+------------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 7, 12, 0, 0), max(tx_datetime)=datetime.datetime(2021, 8, 10, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46987371|
# +-------------------------------+
#
# 2021-08-11.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
# |  count|            46998055|          46998055|          46995956|         46998055|           46998055|         46998055|            46998055|           46998055|
# |   mean|1.1513531200000002E9|500450.50609781616|27036.606355980926|54.23016747395144|6.350292777386343E7| 734.498011034712|0.050680884560009985|0.10220982549171449|
# | stddev|1.3567169997156974E7|288589.48375322815|1540953.0596599067|41.37346999850517|  772810.5838001468|8.655382759681142| 0.21934523820665414|0.44453485119363956|
# |    min|          1127854093|           -999999|                 0|              0.0|              28408|              720|                   0|                  0|
# |    25%|       1.139601911E9|            250775|               197|            21.95|           62855799|              727|                   0|                  0|
# |    50%|       1.151352704E9|            500793|               511|             45.4|           63502497|              734|                   0|                  0|
# |    75%|       1.163103564E9|            750241|               797|            77.77|           64151868|              742|                   0|                  0|
# |    max|          1174852147|            999999|          89518096|         11027.43|           64800000|              749|                   1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 8, 11, 0, 0), max(tx_datetime)=datetime.datetime(2021, 9, 9, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46998055|
# +-------------------------------+
#
# 2021-09-10.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            46994607|          46994607|          46993698|         46994607|           46994607|         46994607|           46994607|           46994607|
# |   mean|  1.19834941298108E9| 500445.8470407466|  26636.0243204525|54.23136454231865|6.609532193275799E7|764.4993277207319|0.05588551894901472|0.11262907252315144|
# | stddev|1.3566154055257775E7|288635.15841756744|1529278.1550647288| 41.2775885733103|  765693.8833488798|8.654688817413973|0.22970051990264512|0.46500817415790213|
# |    min|          1174852148|           -999999|                 0|              0.0|               6149|              750|                  0|                  0|
# |    25%|       1.186597617E9|            250785|               198|            21.95|           65447927|              757|                  0|                  0|
# |    50%|       1.198346238E9|            500829|               511|            45.41|           66096705|              764|                  0|                  0|
# |    75%|       1.210097252E9|            750250|               797|            77.78|           66743946|              772|                  0|                  0|
# |    max|          1221846679|            999999|          89518096|          5837.62|           67392000|              779|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 9, 10, 0, 0), max(tx_datetime)=datetime.datetime(2021, 10, 9, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994532|
# +-------------------------------+
#
# 2021-10-10.txt
# +-------+--------------------+-----------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|   tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
# |  count|            46994093|         46994093|          46993930|         46994093|          46994093|         46994093|           46994093|           46994093|
# |   mean|       1.245343726E9|500423.6408433715| 22810.56163747105|54.23978582052861|6.86878981969399E7|794.4997907290178|0.06448897736998563|0.12984359544932594|
# | stddev|1.3566026266273683E7|288622.3600908985|1412961.9175454574|41.30735488709191| 750625.9412541908|8.656256689670084| 0.2456219665492903| 0.4965055361471538|
# |    min|          1221846680|          -999999|                 0|              0.0|            851620|              780|                  0|                  0|
# |    25%|       1.233595987E9|           250814|               198|            21.95|          68039768|              787|                  0|                  0|
# |    50%|       1.245340812E9|           500725|               511|            45.41|          68688000|              794|                  0|                  0|
# |    75%|       1.257088049E9|           750161|               797|            77.79|          69336061|              802|                  0|                  0|
# |    max|          1268840772|           999999|          89518096|          4852.88|          69984000|              809|                  1|                  3|
# +-------+--------------------+-----------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 10, 10, 0, 0), max(tx_datetime)=datetime.datetime(2021, 11, 8, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46994093|
# +-------------------------------+
#
# 2021-11-09.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            46993018|          46993018|          46991012|         46993018|           46993018|         46993018|           46993018|           46993018|
# |   mean|1.2923372651703408E9| 500413.9063292764| 19519.82502441105|54.23292142717864|7.128008886591358E7| 824.501027578182|0.07662825571236986|0.15411759678852718|
# | stddev| 1.356570545875071E7|288572.73565607535|1304624.3149601328|41.33008500987369|  748060.0050413831|8.655515711540657| 0.2660006910602443| 0.5367729389445526|
# |    min|          1268840773|           -999999|                 0|              0.0|           69984000|              810|                  0|                  0|
# |    25%|        1.28058618E9|            250682|               197|            21.95|           70631941|              817|                  0|                  0|
# |    50%|       1.292337008E9|            500785|               511|            45.41|           71280042|              825|                  0|                  0|
# |    75%|       1.304087505E9|            750165|               797|            77.78|           71928000|              832|                  0|                  0|
# |    max|          1315833756|            999999|          89518096|          4990.09|           72576000|              839|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 11, 9, 0, 0), max(tx_datetime)=datetime.datetime(2021, 12, 8, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46992984|
# +-------------------------------+
#
# 2021-12-09.txt
# +-------+--------------------+-----------------+------------------+-----------------+-------------------+-----------------+-------------------+------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud| tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+-------------------+-----------------+-------------------+------------------+
# |  count|            47001969|         47001969|          47001969|         47001969|           47001969|         47001969|           47001969|          47001969|
# |   mean|       1.339334741E9|500409.7694467864|26246.448202116808|54.22935691864334|7.387152978256766E7|854.4995982615111|0.05260049850252018|0.1060552590892522|
# | stddev|1.3568299871633852E7|  288555.18635652|1517847.4902081003|41.49307547834513|  761919.6830379559|8.655188886754797|0.22323460108158336|0.4522327734192752|
# |    min|          1315833757|                0|                 0|              0.0|             113344|              840|                  0|                 0|
# |    25%|       1.327583175E9|           250752|               197|            21.95|           73223855|              847|                  0|                 0|
# |    50%|       1.339330329E9|           500749|               511|             45.4|           73872000|              854|                  0|                 0|
# |    75%|       1.351081015E9|           750137|               797|            77.78|           74520021|              862|                  0|                 0|
# |    max|          1362835725|           999999|          89518096|         11126.96|           75168000|              869|                  1|                 3|
# +-------+--------------------+-----------------+------------------+-----------------+-------------------+-----------------+-------------------+------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2021, 12, 9, 0, 0), max(tx_datetime)=datetime.datetime(2022, 1, 7, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47001969|
# +-------------------------------+
#
# 2022-01-08.txt
# +-------+--------------------+-----------------+------------------+------------------+-------------------+-----------------+------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|    tx_time_seconds|     tx_time_days|          tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+-----------------+------------------+-------------------+
# |  count|            46997815|         46997815|          46996335|          46997815|           46997815|         46997815|          46997815|           46997815|
# |   mean|1.3863345704952726E9|500428.9917560423|19280.483371501203|54.240334290647915|7.646406779160137E7|884.5008733278345|0.0887910214549336|0.17845308340398378|
# | stddev| 1.356706360416452E7| 288574.733263642|1296359.0654380692| 41.25915955175134|  748250.3711904426| 8.65552830722659|0.2844418704857513| 0.5733438783111914|
# |    min|          1362835726|                0|                 0|               0.0|           22590482|              870|                 0|                  0|
# |    25%|       1.374584408E9|           250713|               200|             21.95|           75815963|              877|                 0|                  0|
# |    50%|       1.386334881E9|           500771|               512|             45.41|           76464032|              884|                 0|                  0|
# |    75%|       1.398079664E9|           750218|               797|              77.8|           77112019|              892|                 0|                  0|
# |    max|          1409833415|           999999|          89518096|           5155.81|           77760000|              899|                 1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+-----------------+------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 1, 8, 0, 0), max(tx_datetime)=datetime.datetime(2022, 2, 6, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46997690|
# +-------------------------------+
#
# 2022-02-07.txt
# +-------+--------------------+-----------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
# |  count|            47005087|         47005087|          47003661|         47005087|           47005087|         47005087|           47005087|           47005087|
# |   mean|1.4333359503378341E9| 500424.354915118| 25125.79786144743|54.23458173388757|7.905503176949225E7|914.5003374634749|0.05723974088166245|0.11534643048315175|
# | stddev|1.3569194966030585E7|288609.0793455189|1484449.2246732442|41.24678541870336|  781892.8976130667|8.655740141832212|0.23230013795410184| 0.4701848749766806|
# |    min|          1409833416|          -999999|                 0|              0.0|               1807|              900|                  0|                  0|
# |    25%|       1.421582294E9|           250801|               198|            21.95|           78407927|              907|                  0|                  0|
# |    50%|       1.433336176E9|           500731|               511|            45.42|           79056000|              915|                  0|                  0|
# |    75%|       1.445088836E9|           750190|               797|            77.79|           79703975|              922|                  0|                  0|
# |    max|          1456838484|           999999|          89518096|          4392.73|           80352000|              929|                  1|                  3|
# +-------+--------------------+-----------------+------------------+-----------------+-------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 2, 7, 0, 0), max(tx_datetime)=datetime.datetime(2022, 3, 8, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47005069|
# +-------------------------------+
#
# 2022-03-09.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|     tx_time_days|            tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
# |  count|            46992441|          46992441|          46992069|         46992441|           46992441|         46992441|            46992441|           46992441|
# |   mean|1.4803346233352947E9| 500414.2857480845|26549.331873469968|54.24050028833435|8.164804158703375E7|944.5005283083719|0.054353252260294374| 0.1095767083050655|
# | stddev| 1.356550532740019E7|288544.64347291493|1526739.3680073095| 41.3024047606864|  748020.7354637199| 8.65507241122361| 0.22671342554598312|0.45917562911787535|
# |    min|          1456838485|                 0|                 0|              0.0|           80352000|              930|                   0|                  0|
# |    25%|       1.468586792E9|            250796|               197|            21.95|           81000021|              937|                   0|                  0|
# |    50%|       1.480334806E9|            500747|               511|            45.41|           81648883|              944|                   0|                  0|
# |    75%|       1.492084181E9|            750179|               797|             77.8|           82296025|              952|                   0|                  0|
# |    max|          1503830765|            999999|          89518096|          4234.83|           82944000|              959|                   1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+-----------------+--------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 3, 9, 0, 0), max(tx_datetime)=datetime.datetime(2022, 4, 7, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46992281|
# +-------------------------------+
#
# 2022-04-08.txt
# +-------+-------------------+-----------------+------------------+------------------+-------------------+-----------------+-------------------+------------------+
# |summary|    # tranaction_id|      customer_id|       terminal_id|         tx_amount|    tx_time_seconds|     tx_time_days|           tx_fraud| tx_fraud_scenario|
# +-------+-------------------+-----------------+------------------+------------------+-------------------+-----------------+-------------------+------------------+
# |  count|           46987223|         46987223|          46986687|          46987223|           46987223|         46987223|           46987223|          46987223|
# |   mean|1.527324299394063E9|500390.6142393433|17168.348523465807| 54.22763825710683|8.423999222281283E7|974.4999270972025|0.08549666789203525|0.1718685098712899|
# | stddev|1.356400034962621E7|288601.8577326057| 1221335.565643906|41.297443865441295|  748029.7289470921|8.655201520070202| 0.2796193650936924|0.5638080705876123|
# |    min|         1503830766|          -999999|                 0|               0.0|           82944000|              960|                  0|                 0|
# |    25%|       1.51557302E9|           250706|               197|             21.95|           83591937|              967|                  0|                 0|
# |    50%|       1.52732483E9|           500767|               511|              45.4|           84239400|              974|                  0|                 0|
# |    75%|      1.539066762E9|           750188|               796|             77.77|           84887988|              982|                  0|                 0|
# |    max|         1550817839|           999999|          89518096|            3657.9|           85536000|              989|                  1|                 3|
# +-------+-------------------+-----------------+------------------+------------------+-------------------+-----------------+-------------------+------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 4, 8, 0, 0), max(tx_datetime)=datetime.datetime(2022, 5, 7, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46987074|
# +-------------------------------+
#
# 2022-05-08.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |  count|            46993169|          46993169|          46992920|         46993169|           46993169|          46993169|           46993169|           46993169|
# |   mean|1.5743143337177281E9|500447.41100982146| 22536.79107678348|54.24149561928916|8.683203009648174E7|1004.5003288882262|0.06965184663328408|0.14017586258121897|
# | stddev|1.3565707140852263E7|288600.50090799417|1404265.2735483472|41.31853611829432|  748037.0202472549| 8.655259424690408| 0.2545593610001227| 0.5141817437350475|
# |    min|          1550817840|           -999999|                 0|              0.0|           85536000|               990|                  0|                  0|
# |    25%|       1.562563239E9|            250814|               198|            21.95|           86184000|               997|                  0|                  0|
# |    50%|       1.574315163E9|            500831|               511|            45.41|           86832980|              1004|                  0|                  0|
# |    75%|       1.586061111E9|            750218|               797|            77.79|           87479963|              1012|                  0|                  0|
# |    max|          1597810822|            999999|          89518096|          4994.57|           88128000|              1019|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 5, 8, 0, 0), max(tx_datetime)=datetime.datetime(2022, 6, 6, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46992983|
# +-------------------------------+
#
# 2022-06-07.txt
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|        tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
# |  count|            46992461|          46992461|          46988785|         46992461|           46992461|          46992461|           46992461|           46992461|
# |   mean|1.6213069912194917E9|500388.15382788744| 23525.82814575861|54.23502812972436|8.942393602357237E7|1034.4992611900025| 0.0639612809382339|0.12878306160641384|
# | stddev|1.3565517012089198E7|288624.61879254336|1435419.4484826748| 41.2974856019447|  748030.5523317595| 8.655264785950994|0.24468395279015137|0.49461143156554344|
# |    min|          1597810823|           -999999|                 0|              0.0|           88128000|              1020|                  0|                  0|
# |    25%|       1.609555857E9|            250697|               198|            21.95|           88775837|              1027|                  0|                  0|
# |    50%|       1.621306028E9|            500644|               511|             45.4|           89423565|              1034|                  0|                  0|
# |    75%|       1.633055476E9|            750253|               797|            77.79|           90071934|              1042|                  0|                  0|
# |    max|          1644803155|            999999|          89518096|          4222.31|           90720000|              1049|                  1|                  3|
# +-------+--------------------+------------------+------------------+-----------------+-------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 6, 7, 0, 0), max(tx_datetime)=datetime.datetime(2022, 7, 6, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46992333|
# +-------------------------------+
#
# 2022-07-07.txt
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|    tx_time_seconds|      tx_time_days|          tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+------------------+-------------------+
# |  count|            46996444|         46996444|          46996163|          46996444|           46996444|          46996444|          46996444|           46996444|
# |   mean|1.6683013775000002E9|500407.9880270303|19506.212597866765| 54.23274718146729|9.201549703749348E7|1064.4987456923336|0.0783479703272869|0.15755087767917078|
# | stddev|1.3566704941515185E7|288616.1909102904|1304160.8023436563|41.421896714337656|  763891.6480208809| 8.655078904130875|0.2687183793665253| 0.5421266547329644|
# |    min|          1644803156|          -999999|                 0|               0.0|              87990|              1050|                 0|                  0|
# |    25%|       1.656550629E9|           250797|               197|             21.95|           91367799|              1057|                 0|                  0|
# |    50%|       1.668298133E9|           500728|               511|              45.4|           92014300|              1064|                 0|                  0|
# |    75%|       1.680048926E9|           750198|               796|             77.77|           92663871|              1072|                 0|                  0|
# |    max|          1691799599|           999999|          89518096|          16539.04|           93312000|              1079|                 1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 7, 7, 0, 0), max(tx_datetime)=datetime.datetime(2022, 8, 5, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46996444|
# +-------------------------------+
#
# 2022-08-06.txt
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+------------------+
# |summary|     # tranaction_id|       customer_id|       terminal_id|         tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud| tx_fraud_scenario|
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+------------------+
# |  count|            47002232|          47002232|          47002232|          47002232|           47002232|          47002232|           47002232|          47002232|
# |   mean| 1.715300608913072E9|500340.53763291496|21321.256482202803|54.226224172503194|9.460679685314481E7|1094.4999373646767|0.07931025488321491|0.1594757031963929|
# | stddev|1.3568313447060063E7|288616.99627891724| 1364987.478518134| 41.24403581969993|  796774.4338387891|  8.65485800277187|  0.270222389722096|0.5451031295222581|
# |    min|          1691799600|           -999999|                 0|               0.0|             209906|              1080|                  0|                 0|
# |    25%|       1.703548711E9|            250670|               198|             21.95|           93959985|              1087|                  0|                 0|
# |    50%|       1.715299744E9|            500643|               511|             45.41|           94606858|              1094|                  0|                 0|
# |    75%|       1.727049166E9|            750107|               797|             77.77|           95255971|              1102|                  0|                 0|
# |    max|          1738801609|            999999|          89518096|            4044.3|           95904000|              1109|                  1|                 3|
# +-------+--------------------+------------------+------------------+------------------+-------------------+------------------+-------------------+------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 8, 6, 0, 0), max(tx_datetime)=datetime.datetime(2022, 9, 4, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       47002010|
# +-------------------------------+
#
# 2022-09-05.txt
# +-------+--------------------+-----------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|   tx_time_seconds|     tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
# |  count|            46993904|         46993904|          46993491|         46993904|          46993904|         46993904|           46993904|           46993904|
# |   mean|1.7622985251184585E9|500451.4223348841|  26879.9722196208|54.22865285548542|9.71999573775784E7|1124.499529811356|0.05413310628544502|0.10908421228421457|
# | stddev| 1.356595293632072E7|288557.9335266993|1536397.0764265126|41.26262298775377| 748045.1067486721|8.655393634483925|0.22628016744490592|0.45806161067937434|
# |    min|          1738801610|                0|                 0|              0.0|          95904000|             1110|                  0|                  0|
# |    25%|       1.750547101E9|           250793|               197|            21.95|          96551921|             1117|                  0|                  0|
# |    50%|         1.7622979E9|           500819|               511|            45.41|          97198023|             1124|                  0|                  0|
# |    75%|       1.774047579E9|           750204|               797|            77.78|          97848022|             1132|                  0|                  0|
# |    max|          1785795451|           999999|          89518096|          3823.85|          98496000|             1139|                  1|                  3|
# +-------+--------------------+-----------------+------------------+-----------------+------------------+-----------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 9, 5, 0, 0), max(tx_datetime)=datetime.datetime(2022, 10, 4, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46993842|
# +-------------------------------+
#
# 2022-10-05.txt
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+-------------------+-------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|         tx_amount|    tx_time_seconds|      tx_time_days|           tx_fraud|  tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+-------------------+-------------------+
# |  count|            46997187|         46997187|          46996628|          46997187|           46997187|          46997187|           46997187|           46997187|
# |   mean|1.8092940308254435E9|500403.2466955735| 25236.37741297099| 54.22406974783355|9.979193856756206E7|1154.4993281406396|0.06403727950781395|0.12892505672733137|
# | stddev|1.3566909908748813E7|288567.8257958096|1487771.0287754794|41.255039432508035|  748069.1107095674|  8.65563086220305| 0.2448193366880441| 0.4948289254937772|
# |    min|          1785795452|                0|                 0|               0.0|           98496000|              1140|                  0|                  0|
# |    25%|       1.797543527E9|           250727|               198|             21.94|           99143957|              1147|                  0|                  0|
# |    50%|       1.809292755E9|           500700|               511|              45.4|           99791108|              1154|                  0|                  0|
# |    75%|       1.821045211E9|           750148|               797|             77.79|          100439994|              1162|                  0|                  0|
# |    max|          1832792609|           999999|          89518096|           5310.46|          101088000|              1169|                  1|                  3|
# +-------+--------------------+-----------------+------------------+------------------+-------------------+------------------+-------------------+-------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 10, 5, 0, 0), max(tx_datetime)=datetime.datetime(2022, 11, 3, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46997158|
# +-------------------------------+
#
# 2022-11-04.txt
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+------------------+-------------------+--------------------+
# |summary|     # tranaction_id|      customer_id|       terminal_id|        tx_amount|     tx_time_seconds|      tx_time_days|           tx_fraud|   tx_fraud_scenario|
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+------------------+-------------------+--------------------+
# |  count|            46998983|         46998983|          46996685|         46998983|            46998983|          46998983|           46998983|            46998983|
# |   mean|1.8562920966245558E9| 500437.420257349|28085.477290004605|54.17185979556221|1.0238400246815348E8|1184.5000234154004|0.02991875377388485|0.060363710423265965|
# | stddev|1.3567435381965658E7|288558.3518378499| 1571112.249845114|40.93842760395922|   748058.0447052694| 8.655529240607343|0.17036320777691383| 0.34608998632486965|
# |    min|          1832792610|          -999999|                 0|              0.0|           101088000|              1170|                  0|                   0|
# |    25%|       1.844541887E9|           250767|               196|            21.95|           101735921|              1177|                  0|                   0|
# |    50%|       1.856291002E9|           500785|               511|            45.41|           102383050|              1184|                  0|                   0|
# |    75%|       1.868037481E9|           750180|               797|            77.77|           103031923|              1192|                  0|                   0|
# |    max|          1879791584|           999999|          89518096|           4754.5|           103680000|              1199|                  1|                   3|
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+------------------+-------------------+--------------------+
#
# Row(min(tx_datetime)=datetime.datetime(2022, 11, 4, 0, 0), max(tx_datetime)=datetime.datetime(2022, 12, 3, 23, 59, 59))
# +-------------------------------+
# |count(DISTINCT # tranaction_id)|
# +-------------------------------+
# |                       46998975|
# +-------------------------------+

# %% [markdown]
# * tx_datetime: поиск значений, которые выпадают за требуемые ограничения (часы, минуты и т.п.)

# %%
def add_info(path):
    data = spark.read.text(path)
    header=data.first()[0]
    schema=header.split(" | ")
    df_new = data.filter(data["value"] != header).rdd.map(lambda x:x[0].split(",")).toDF(schema)
    df_new = df_new.withColumn("tx_datetime", df_new.tx_datetime.cast(TimestampType()))\
                   .withColumn("hour", hour(col("tx_datetime")))\
                   .withColumn("minute", minute(col("tx_datetime")))\
                   .withColumn("second", second(col("tx_datetime")))
    print(df_new.select(min("hour"), max("hour"), min("minute"), max("minute"), min("second"), max("second")).first())

# %%
for path in all_dart_dirs:
    print(str(path)[2:-1])
    add_info(str(path)[2:-1])
# Out:
# 2019-08-22.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2019-09-21.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2019-10-21.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2019-11-20.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2019-12-20.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-01-19.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-02-18.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-03-19.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-04-18.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-05-18.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-06-17.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-07-17.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-08-16.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-09-15.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-10-15.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-11-14.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2020-12-14.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-01-13.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-02-12.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-03-14.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-04-13.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-05-13.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-06-12.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-07-12.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-08-11.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-09-10.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-10-10.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-11-09.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2021-12-09.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-01-08.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-02-07.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-03-09.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-04-08.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-05-08.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-06-07.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-07-07.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-08-06.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-09-05.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-10-05.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)
# 2022-11-04.txt
# Row(min(hour)=0, max(hour)=23, min(minute)=0, max(minute)=59, min(second)=0, max(second)=59)

# %% [markdown]
# Дубликаты строк

# %%
df_new.filter(df_new['# tranaction_id'] == 3600373).show(truncate=False)
# Out:
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |# tranaction_id|tx_datetime        |customer_id|terminal_id|tx_amount|tx_time_seconds|tx_time_days|tx_fraud|tx_fraud_scenario|
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+
# |3600373        |2019-08-24 19:52:51|299409     |539        |33.25    |244371         |2           |0       |0                |
# |3600373        |2019-08-24 19:52:51|299409     |539        |33.25    |244371         |2           |0       |0                |
# +---------------+-------------------+-----------+-----------+---------+---------------+------------+--------+-----------------+

# %%
spark.stop()
